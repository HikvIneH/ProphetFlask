# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
import pickle
import datetime
import matplotlib.pyplot as plt


import os.path
import fix_yahoo_finance as yf
import pandas as pd

plt.rcParams['figure.figsize']=(20,10)
plt.style.use('ggplot')

# %%
h = 6
endDate = datetime.datetime.now().date()
startDate = datetime.datetime.strptime(str(endDate), u'%Y-%m-%d').date() - datetime.timedelta(days=h)
print startDate
# Out:
# 2018-11-05

# %%
startDate = datetime.datetime(2015, 1, 4).date()
endDate = datetime.datetime.now().date()
print startDate
# Out:
# 2015-01-04

# %%
df_historical = pd.read_csv("BTC-USD.csv")

# %%
df_historical.tail()
# Out:
#            Date         Open         High          Low        Close  \
# 361  2018-11-05  6467.049805  6475.799805  6406.689941  6433.740234
# 362  2018-11-06  6433.529785  6482.810059  6412.560059  6479.720215
# 363  2018-11-07  6479.720215  6562.790039  6476.589844  6529.680176
# 364  2018-11-08  6530.939941  6542.419922  6438.270020  6446.060059
# 365  2018-11-09  6446.060059  6457.970215  6358.819824  6378.779785
#
#        Adj Close     Volume
# 361  6433.740234  155758902
# 362  6479.720215  239808254
# 363  6529.680176  360052788
# 364  6446.060059  273205386
# 365  6378.779785  174106736

# %%
def get_historical_stock_price(stock):
    print ("Getting historical stock prices for stock ", stock)
    stockData = yf.download(stock, startDate, endDate)
    stockData.to_csv(stock+'-'+str(startDate)+'to'+str(endDate)+".csv")
    return stockData

# %%
stock = 'aapl'
if os.path.isfile("./app/static/data/"+stock+'-'+str(startDate)+'to'+str(endDate)+".csv") == False: 
    df_historical = get_historical_stock_price(stock)
    df_historical = pd.DataFrame(data=df_historical)
    df_historical.to_csv("./app/static/data/"+stock+'-'+str(startDate)+'to'+str(endDate)+".csv")
else:
    df_historical = pd.read_csv("./app/static/data/"+stock+'-'+str(startDate)+'to'+str(endDate)+".csv", index_col=[0])
    print 'opened'
# Out:
# opened

# %%
df = pd.DataFrame(data=df_historical)

# %%
df.tail()
# Out:
#            Date         Open         High          Low        Close  \
# 361  2018-11-05  6467.049805  6475.799805  6406.689941  6433.740234
# 362  2018-11-06  6433.529785  6482.810059  6412.560059  6479.720215
# 363  2018-11-07  6479.720215  6562.790039  6476.589844  6529.680176
# 364  2018-11-08  6530.939941  6542.419922  6438.270020  6446.060059
# 365  2018-11-09  6446.060059  6457.970215  6358.819824  6378.779785
#
#        Adj Close     Volume
# 361  6433.740234  155758902
# 362  6479.720215  239808254
# 363  6529.680176  360052788
# 364  6446.060059  273205386
# 365  6378.779785  174106736

# %%
dfr = df_historical.round(3)
df = pd.DataFrame(data=dfr)
df = dfr.filter(['Close'])
dfa = dfr.filter(['Close'])

# %%
df['ds'] = df.index
dfa['ds'] = df.index
dfa.tail()
# Out:
#              Close          ds
# Date
# 2018-10-30  213.30  2018-10-30
# 2018-10-31  218.86  2018-10-31
# 2018-11-01  222.22  2018-11-01
# 2018-11-02  207.48  2018-11-02
# 2018-11-05  201.59  2018-11-05

# %%
#log transform 'Close' from non-stationary to stationary
df['y'] = np.log(df['Close']).round(3)
df.tail()
# Out:
#              Close          ds      y
# Date
# 2018-10-30  213.30  2018-10-30  5.363
# 2018-10-31  218.86  2018-10-31  5.388
# 2018-11-01  222.22  2018-11-01  5.404
# 2018-11-02  207.48  2018-11-02  5.335
# 2018-11-05  201.59  2018-11-05  5.306

# %%
#model = Prophet(weekly_seasonality=True, daily_seasonality=True, yearly_seasonality=True)
if os.path.isfile("./app/static/data/"+"pickle.pckl") == False: 
    model = Prophet()
    model.fit(df)
    with open("./app/static/data/"+"pickle.pckl", "wb") as f:
        pickle.dump(model, f)
else:
    with open("./app/static/data/"+"pickle.pckl", "rb") as f:
        model = pickle.load(f)
        print 'opened'
# Out:
# opened

# %%
sekarang = startDate+"-"+endDate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1341f47cbbd9> in <module>()
# ----> 1 sekarang = startDate+"-"+endDate
#
# TypeError: unsupported operand type(s) for +: 'datetime.date' and 'str'

# %%
sekarang + 'pickle'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3f5b86b68d3c> in <module>()
# ----> 1 sekarang + 'pickle'
#
# NameError: name 'sekarang' is not defined

# %%
import celery

# email
import fbprophet
from flask import current_app


@celery.task(name='creating_model')
def predict_async_model(a):
    """ Background task to predict model with prophet."""
    app = current_app._get_current_object()
    # send the email
    model = prophet()
    with app.app_context():
        model.fit(a)

# %%
model = Prophet()
model.fit(df)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#Prophet().fit(df)

# %%
num_days = 30

# %%
future = model.make_future_dataframe(periods=num_days)
#forecast = model.predict(future)
    
#print (forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

# %%
forecast = model.predict(future)

# %%
print (forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 993 2018-12-01  5.390401    5.349461    5.429129
# 994 2018-12-02  5.391451    5.351836    5.432067
# 995 2018-12-03  5.414733    5.374719    5.454518
# 996 2018-12-04  5.416501    5.377131    5.456156
# 997 2018-12-05  5.418202    5.377529    5.460265

# %%
#Prophet plots the observed values of our time series (the black dots), the forecasted values (blue line) and
#the uncertainty intervalsof our forecasts (the blue shaded regions).
from fbprophet.plot import add_changepoints_to_plot

fig1 = model.plot(forecast)
fig1.show()
fig2 = model.plot_components(forecast)
fig2.show()
a = add_changepoints_to_plot(fig1.gca(), model, forecast)

# %%
a = add_changepoints_to_plot(fig1.gca(), model, forecast)

# %%
df.tail()
# Out:
#               Close         ds      y
# Date
# 2018-10-30  213.300 2018-10-30  5.363
# 2018-10-31  218.860 2018-10-31  5.388
# 2018-11-01  222.220 2018-11-01  5.404
# 2018-11-02  207.480 2018-11-02  5.335
# 2018-11-05  201.025 2018-11-05  5.303

# %%
m = Prophet(weekly_seasonality=False)
m.add_seasonality(name='monthly', period=365, fourier_order=5)
forecast = m.fit(df).predict(future)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m = Prophet(mcmc_samples=300)
forecast = m.fit(df).predict(future)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='1095 days', period='30,5 days', horizon = '365 days')
# Out:
# INFO:fbprophet.diagnostics:Making 6 forecasts with cutoffs between 2013-08-23 00:00:00 and 2017-10-26 00:00:00

# %%
df

# %%
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)

# %%
from fbprophet.plot import plot_cross_validation_metric

plot_cross_validation_metric(df_cv, metric='mape')

# %%
df.tail()
# Out:
#              Close      y
# ds
# 2018-10-22  220.65  5.397
# 2018-10-23  222.73  5.406
# 2018-10-24  215.09  5.371
# 2018-10-25  219.80  5.393
# 2018-10-26  216.30  5.377

# %%
df.set_index('ds', inplace=True)
forecast.set_index('ds', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-0abf53316b1a> in <module>()
# ----> 1 df.set_index('ds', inplace=True)
#       2 forecast.set_index('ds', inplace=True)
#
# /home/bepraset/Workspaces/Anaconda/envs/python27/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# /home/bepraset/Workspaces/Anaconda/envs/python27/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /home/bepraset/Workspaces/Anaconda/envs/python27/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /home/bepraset/Workspaces/Anaconda/envs/python27/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /home/bepraset/Workspaces/Anaconda/envs/python27/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /home/bepraset/Workspaces/Anaconda/envs/python27/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'

# %%
viz_df = df.join(forecast[['yhat', 'yhat_lower','yhat_upper']], how = 'outer')

# %%
viz_df.tail()
viz_df['yhat_scaled'] = np.exp(viz_df['yhat'])
forecasted_data = viz_df.yhat_scaled
forecasted_data.tail()
viz_df.tail(30)
# Out:
#             Close   y      yhat  yhat_lower  yhat_upper  yhat_scaled
# ds
# 2018-10-27    NaN NaN  5.418143    5.358348    5.471440   225.460163
# 2018-10-28    NaN NaN  5.418646    5.363644    5.474793   225.573402
# 2018-10-29    NaN NaN  5.393153    5.335773    5.446318   219.895662
# 2018-10-30    NaN NaN  5.393771    5.336800    5.446696   220.031633
# 2018-10-31    NaN NaN  5.393581    5.340887    5.449975   219.989652
# 2018-11-01    NaN NaN  5.391853    5.336933    5.444403   219.609907
# 2018-11-09    217.402060
# 2018-11-10    223.384121
# 2018-11-11    223.197104
# 2018-11-12    217.383004
# 2018-11-13    217.421235
# 2018-11-14    217.385600
# 2018-11-15    217.117300
# 2018-11-16    216.767479
# 2018-11-17    223.061793
# 2018-11-18    223.227273
# 2018-11-19    217.767912
# 2018-11-20    218.164151
# 2018-11-21    218.478391
# 2018-11-22    218.540376
# 2018-11-23    218.491877
# 2018-11-24    225.111320
# 2018-11-25    225.508116
# Name: yhat, dtype: float64
# Prediction quality: 7.51 MSE (2.74 RMSE)

# %%
#make the vizualization a little better to understand

#date = df['ds'].tail(plot_num)

viz_df = df.join(forecast[['yhat', 'yhat_lower','yhat_upper']], how = 'outer')
viz_df['yhat_scaled'] = np.exp(viz_df['yhat'])

close_data = viz_df.Close
forecasted_data = viz_df.yhat_scaled
date = future['ds']
#date = viz_df.index[-plot_num:-1]
forecast_start = forecasted_data[-num_days]
forecast_future = forecasted_data[-1]

# %%
viz_df.tail(31)
# Out:
#             Close      y      yhat  yhat_lower  yhat_upper  yhat_scaled
# ds
# 2018-10-26  216.3  5.377  5.389256    5.335961    5.445758   219.040306
# 2018-10-27    NaN    NaN  5.418143    5.358348    5.471440   225.460163
# 2018-10-28    NaN    NaN  5.418646    5.363644    5.474793   225.573402
# 2018-10-29    NaN    NaN  5.393153    5.335773    5.446318   219.895662
# 2018-10-30    NaN    NaN  5.393771    5.336800    5.446696   220.031633
# 2018-10-31    NaN    NaN  5.393581    5.340887    5.449975   219.989652
# 2018-11-01    NaN    NaN  5.391853    5.336933    5.444403   219.609907
# 2018-11-02    NaN    NaN  5.389298    5.335052    5.445022   219.049562
# 2018-11-03    NaN    NaN  5.416558    5.363728    5.467399   225.103059
# 2018-11-04    NaN    NaN  5.415556    5.360711    5.471179   224.877541
# 2018-11-05    NaN    NaN  5.388722    5.332363    5.442361   218.923354
# 2018-11-06    NaN    NaN  5.388196    5.335334    5.441354   218.808297
# 2018-11-07    NaN    NaN  5.387089    5.331179    5.437296   218.566303
# 2018-11-08    NaN    NaN  5.384698    5.333251    5.441542   218.044238
# 2018-11-09    NaN    NaN  5.381748    5.325747    5.437151   217.402060
# 2018-11-10    NaN    NaN  5.408893    5.356921    5.460045   223.384121
# 2018-11-11    NaN    NaN  5.408055    5.356785    5.460764   223.197104
# 2018-11-12    NaN    NaN  5.381661    5.328608    5.436295   217.383004
# 2018-11-13    NaN    NaN  5.381837    5.326712    5.439022   217.421235
# 2018-11-14    NaN    NaN  5.381673    5.325500    5.434598   217.385600
# 2018-11-15    NaN    NaN  5.380438    5.323351    5.430837   217.117300
# 2018-11-16    NaN    NaN  5.378825    5.323681    5.435489   216.767479
# 2018-11-17    NaN    NaN  5.407449    5.348963    5.463776   223.061793
# 2018-11-18    NaN    NaN  5.408190    5.351159    5.462423   223.227273
# 2018-11-19    NaN    NaN  5.383430    5.324991    5.439175   217.767912
# 2018-11-20    NaN    NaN  5.385248    5.325317    5.438515   218.164151
# 2018-11-21    NaN    NaN  5.386687    5.327859    5.445140   218.478391
# 2018-11-22    NaN    NaN  5.386971    5.333117    5.441177   218.540376
# 2018-11-23    NaN    NaN  5.386749    5.334256    5.444397   218.491877
# 2018-11-24    NaN    NaN  5.416595    5.360489    5.472895   225.111320
# 2018-11-25    NaN    NaN  5.418356    5.366149    5.472163   225.508116
