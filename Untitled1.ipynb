# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
import pickle
import datetime
import matplotlib.pyplot as plt


import os.path
import fix_yahoo_finance as yf
import pandas as pd

plt.rcParams['figure.figsize']=(20,10)
plt.style.use('ggplot')

# %%
h = 6
endDate = datetime.datetime.now().date()
startDate = datetime.datetime.strptime(str(endDate), u'%Y-%m-%d').date() - datetime.timedelta(days=h)
print startDate
# Out:
# 2018-11-09

# %%
startDate = datetime.datetime(2015, 1, 4).date()
endDate = datetime.datetime.now().date()
print startDate
# Out:
# 2015-01-04

# %%
df_historical = pd.read_csv('./old/international-airline-passengers.csv', index_col=[0], engine='python', skipfooter=3)

# %%
df_historical = pd.read_csv('./old/Bitcoin.csv', index_col=[0])

# %%
df_historical.tail()

# %%
stock ='dsaaaa'
while os.path.isfile(stock+".csv") == False:
    try: 
        df_historical = yf.download(stock, startDate, endDate)
        df_historical.to_csv(stock+".csv")
        print 'success'
        break
        
    except ValueError:
        print 'Yahoo Finance could not return your request. Please try again.'
        break
    else:
        df_historical = pd.read_csv(stock+".csv", index_col=[0])
        print 'opened'

# %%
df = df_historical.filter(['Close'])
df['ds'] = df.index
df['y'] = np.log(df['Close'])
original_end = df['Close'][-1]
df_historical.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-11-08  111.800003  112.209999  110.910004  111.750000  111.269310
# 2018-11-09  110.849998  111.449997  108.760002  109.570000  109.098686
# 2018-11-12  109.419998  109.959999  106.099998  106.870003  106.410301
# 2018-11-13  107.550003  108.739998  106.639999  106.940002  106.480003
# 2018-11-14  108.099998  108.260002  104.470001  104.970001  104.970001
#
#               Volume
# Date
# 2018-11-08  25644100
# 2018-11-09  32039200
# 2018-11-12  33621800
# 2018-11-13  35374600
# 2018-11-14  39476800

# %%
def get_historical_stock_price(stock):
    print ("Getting historical stock prices for stock ", stock)
    while True:
        try:
            stockData = yf.download(stock, startDate, endDate)
            #stockData.to_csv(stock+'-'+str(startDate)+'to'+str(endDate)+".csv")
            break
        except ValueError:
            return 'Oops, yahoo finance could return your request, please try again.'

# %%
stock = 'dsa'
if os.path.isfile(stock+'-'+str(startDate)+'to'+str(endDate)+".csv") == False: 
    df_historical = get_historical_stock_price(stock)
    df_historical = pd.DataFrame(data=df_historical)
    df_historical.to_csv(stock+'-'+str(startDate)+'to'+str(endDate)+".csv")
else:
    df_historical = pd.read_csv(stock+'-'+str(startDate)+'to'+str(endDate)+".csv", index_col=[0])
    print 'opened'
# Out:
# ('Getting historical stock prices for stock ', 'dsa')
# [*********************100%***********************]  1 of 1 downloaded
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-95416a6b9654> in <module>()
#       2 if os.path.isfile(stock+'-'+str(startDate)+'to'+str(endDate)+".csv") == False:
#       3     df_historical = get_historical_stock_price(stock)
# ----> 4     df_historical = pd.DataFrame(data=df_historical)
#       5     df_historical.to_csv(stock+'-'+str(startDate)+'to'+str(endDate)+".csv")
#       6 else:
#
# /home/bepraset/Workspaces/Anaconda/envs/analison/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# ...

# %%
df = pd.DataFrame(data=df_historical)

# %%
df.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dfr = df_historical.round(3)
df = pd.DataFrame(data=dfr)
df = dfr.filter([0])
dfa = dfr.iloc[:,-1]
df.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1960-08, 1960-09, 1960-10, 1960-11, 1960-12]

# %%
df['ds'] = df.index
try:
    df['y'] = np.log(df['Close'])
except KeyError as e:
    print "please change your target to 'Close'"
df.tail()
# Out:
# please change your target to 'Close'
#               ds
# Month
# 1960-08  1960-08
# 1960-09  1960-09
# 1960-10  1960-10
# 1960-11  1960-11
# 1960-12  1960-12

# %%
#log transform 'Close' from non-stationary to stationary
df['y'] = np.log(df.iloc[:,-1]).round(3)
df.tail()
# Out:
#                     ds       y
# Date
# 2018-11-05  2018-11-05  18.864
# 2018-11-06  2018-11-06  19.295
# 2018-11-07  2018-11-07  19.702
# 2018-11-08  2018-11-08  19.426
# 2018-11-09  2018-11-09  18.975

# %%
original_close = dfr.iloc[:,-1][-1]
original_close
# Out:
# 174106736

# %%
#model = Prophet(weekly_seasonality=True, daily_seasonality=True, yearly_seasonality=True)
if os.path.isfile("./app/static/data/"+"pickle.pckl") == False: 
    model = Prophet()
    model.fit(df)
    with open("./app/static/data/"+"pickle.pckl", "wb") as f:
        pickle.dump(model, f)
else:
    with open("./app/static/data/"+"pickle.pckl", "rb") as f:
        model = pickle.load(f)
        print 'opened'
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /home/bepraset/Workspaces/Anaconda/envs/analison/lib/python2.7/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
sekarang = startDate+"-"+endDate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1341f47cbbd9> in <module>()
# ----> 1 sekarang = startDate+"-"+endDate
#
# TypeError: unsupported operand type(s) for +: 'datetime.date' and 'str'

# %%
sekarang + 'pickle'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3f5b86b68d3c> in <module>()
# ----> 1 sekarang + 'pickle'
#
# NameError: name 'sekarang' is not defined

# %%
import celery

# email
import fbprophet
from flask import current_app


@celery.task(name='creating_model')
def predict_async_model(a):
    """ Background task to predict model with prophet."""
    app = current_app._get_current_object()
    # send the email
    model = prophet()
    with app.app_context():
        model.fit(a)

# %%
model = Prophet()
model.fit(df)
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /home/bepraset/Workspaces/Anaconda/envs/analison/lib/python2.7/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
#Prophet().fit(df)

# %%
num_days = 30

# %%
future = model.make_future_dataframe(periods=num_days)
#forecast = model.predict(future)
    
#print (forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

# %%
forecast = model.predict(future)

# %%
print (forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 169 1960-12-27  6.167586    6.123609    6.213292
# 170 1960-12-28  6.160700    6.113955    6.204326
# 171 1960-12-29  6.152563    6.110341    6.200661
# 172 1960-12-30  6.143319    6.098093    6.186089
# 173 1960-12-31  6.133131    6.086366    6.179404

# %%
#Prophet plots the observed values of our time series (the black dots), the forecasted values (blue line) and
#the uncertainty intervalsof our forecasts (the blue shaded regions).
from fbprophet.plot import add_changepoints_to_plot

fig1 = model.plot(forecast)
fig1.show()
fig2 = model.plot_components(forecast)
fig2.show()
a = add_changepoints_to_plot(fig1.gca(), model, forecast)
# Out:
# /home/bepraset/Workspaces/Anaconda/envs/analison/lib/python2.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
a = add_changepoints_to_plot(fig1.gca(), model, forecast)

# %%
df.tail()
# Out:
#               ds      y
# Month
# 1960-08  1960-08  6.407
# 1960-09  1960-09  6.230
# 1960-10  1960-10  6.133
# 1960-11  1960-11  5.966
# 1960-12  1960-12  6.068

# %%
m = Prophet(weekly_seasonality=False)
m.add_seasonality(name='monthly', period=365, fourier_order=5)
forecast = m.fit(df).predict(future)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m = Prophet(mcmc_samples=300)
forecast = m.fit(df).predict(future)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='1095 days', period='30,5 days', horizon = '365 days')
# Out:
# INFO:fbprophet.diagnostics:Making 10 forecasts with cutoffs between 1952-05-27 00:00:00 and 1959-12-02 00:00:00

# %%
df.tail()
# Out:
#               ds      y
# Month
# 1960-08  1960-08  6.407
# 1960-09  1960-09  6.230
# 1960-10  1960-10  6.133
# 1960-11  1960-11  5.966
# 1960-12  1960-12  6.068

# %%
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)

# %%
from fbprophet.plot import plot_cross_validation_metric

plot_cross_validation_metric(df_cv, metric='mape')

# %%
df.tail()
# Out:
#               ds      y
# Month
# 1960-08  1960-08  6.407
# 1960-09  1960-09  6.230
# 1960-10  1960-10  6.133
# 1960-11  1960-11  5.966
# 1960-12  1960-12  6.068

# %%
df.set_index('ds', inplace=True)
forecast.set_index('ds', inplace=True)

# %%
viz_df = df.join(forecast[['yhat', 'yhat_lower','yhat_upper']], how = 'outer')

# %%
viz_df.tail()
viz_df['yhat_scaled'] = np.exp(viz_df['yhat'])
forecasted_data = viz_df.yhat_scaled
forecasted_data.tail()
viz_df.tail(60)
# Out:
#                 y      yhat  yhat_lower  yhat_upper  yhat_scaled
# ds
# 1958-07-01  6.196  6.162033    6.109224    6.216472   474.391351
# 1958-08-01  6.225  6.159588    6.104551    6.212725   473.232867
# 1958-09-01  6.001  6.025835    5.971768    6.076267   413.986994
# 1958-10-01  5.883  5.892680    5.837505    5.944732   362.374993
# 1958-11-01  5.737  5.757039    5.706368    5.806793   316.410105
# 1958-12-01  5.820  5.883195    5.831527    5.938091   358.954443
# 1959-01-01  5.886  5.909826    5.857227    5.966418   368.641937
# 1959-02-01  5.835  5.893837    5.839101    5.946029   362.794795
# 1959-03-01  6.006  6.045848    5.988891    6.101441   422.355577
# 1959-04-01  5.981  6.002749    5.947912    6.054898   404.539533
# 1959-05-01  6.040  6.026006    5.968870    6.077910   414.057875
# 1959-06-01  6.157  6.142335    6.087783    6.196268   465.138480
# 1959-07-01  6.306  6.276909    6.220082    6.333824   532.141493
# ...

# %%
from math import sqrt
y_hatx = np.exp(viz_df['yhat'][-1:])
print y_hatx
y_hat = np.exp(viz_df['yhat'][-31:])
print y_hat
y_true = viz_df.iloc[:,-1]

# compute the mean square error
mse = ((y_hat - y_true) ** 2).mean()

print('Prediction quality: {:.2f} MSE ({:.2f} RMSE)'.format(mse, sqrt(mse)))
# Out:
# ds
# 1960-12-31    461.081202
# Name: yhat, dtype: float64
# ds
# 1960-12-01    444.860760
# 1960-12-02    442.968688
# 1960-12-03    441.832386
# 1960-12-04    441.470777
# 1960-12-05    441.883214
# 1960-12-06    443.050029
# 1960-12-07    444.933144
# 1960-12-08    447.476773
# 1960-12-09    450.608282
# 1960-12-10    454.239271
# 1960-12-11    458.267000
# 1960-12-12    462.576221
# 1960-12-13    467.041511
# 1960-12-14    471.530135
# 1960-12-15    475.905436
# 1960-12-16    480.030693
# 1960-12-17    483.773322
# 1960-12-18    487.009252
# 1960-12-19    489.627238
# 1960-12-20    491.532884
# 1960-12-21    492.652101
# 1960-12-22    492.933782
# 1960-12-23    492.351499
# 1960-12-24    490.904118
# 1960-12-25    488.615276
# 1960-12-26    485.531793
# 1960-12-27    481.721130
# 1960-12-28    477.268092
# 1960-12-29    472.271012
# 1960-12-30    466.837673
# 1960-12-31    461.081202
# Name: yhat, dtype: float64
# Prediction quality: 0.00 MSE (0.00 RMSE)

# %%
#make the vizualization a little better to understand

#date = df['ds'].tail(plot_num)

viz_df = df.join(forecast[['yhat', 'yhat_lower','yhat_upper']], how = 'outer')
viz_df['yhat_scaled'] = np.exp(viz_df['yhat'])

close_data = viz_df.Close
forecasted_data = viz_df.yhat_scaled
date = future['ds']
#date = viz_df.index[-plot_num:-1]
forecast_start = forecasted_data[-num_days]
forecast_future = forecasted_data[-1]

# %%
viz_df.tail(31)
# Out:
#             Close      y      yhat  yhat_lower  yhat_upper  yhat_scaled
# ds
# 2018-10-26  216.3  5.377  5.389256    5.335961    5.445758   219.040306
# 2018-10-27    NaN    NaN  5.418143    5.358348    5.471440   225.460163
# 2018-10-28    NaN    NaN  5.418646    5.363644    5.474793   225.573402
# 2018-10-29    NaN    NaN  5.393153    5.335773    5.446318   219.895662
# 2018-10-30    NaN    NaN  5.393771    5.336800    5.446696   220.031633
# 2018-10-31    NaN    NaN  5.393581    5.340887    5.449975   219.989652
# 2018-11-01    NaN    NaN  5.391853    5.336933    5.444403   219.609907
# 2018-11-02    NaN    NaN  5.389298    5.335052    5.445022   219.049562
# 2018-11-03    NaN    NaN  5.416558    5.363728    5.467399   225.103059
# 2018-11-04    NaN    NaN  5.415556    5.360711    5.471179   224.877541
# 2018-11-05    NaN    NaN  5.388722    5.332363    5.442361   218.923354
# 2018-11-06    NaN    NaN  5.388196    5.335334    5.441354   218.808297
# ...
